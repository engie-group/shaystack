# %%
import haystackapi

# %%
import datetime

# %%
g = haystackapi.Grid()

# %%
g.metadata['aMarker'] = haystackapi.MARKER

# %%
g.metadata['today'] = datetime.date.today()

# %%
g.column['firstColumn'] = {'metaData':'in no particular order', 'abc': 123}

# %%
g.column['secondColumn'] = {}

# %%
g.extend([
    {'firstColumn': haystackapi.Quantity(154, 'kg'), 'secondColumn': 'and counting'},
    {'firstColumn': haystackapi.MARKER, 'secondColumn': 'supported on Python 3.7+'},
    {'firstColumn': haystackapi.Coordinate(-27.4725,153.003),
     'secondColumn': 'Made in Australia from local and imported ingredients'},
])
# Out:
# <Grid>
# 	Version: 3.0
# 	Metadata: MetadataObject{'aMarker'=MARKER, 'today'=datetime.date(2021, 1, 14)}
# 	Columns:
# 		firstColumn: {'metaData': 'in no particular order', 'abc': 123}
# 		secondColumn
# 	Row    0:
# 	firstColumn=_PintQuantity(154, 'kg')
# 	secondColumn='and counting'
# 	Row    1:
# 	firstColumn=MARKER
# 	secondColumn='supported on Python 3.7+'
# 	Row    2:
# 	firstColumn=Coordinate(-27.4725, 153.003)
# 	secondColumn='Made in Australia from local and imported ingredients'
# </Grid>

# %%
print(haystackapi.dump(g))
# Out:
# ver:"3.0" aMarker today:2021-01-14
# firstColumn metaData:"in no particular order" abc:123,secondColumn
# 154kg,"and counting"
# M,"supported on Python 3.7+"
# C(-27.472500,153.003000),"Made in Australia from local and imported ingredients"

# %%
print(haystackapi.dump(g,mode=haystackapi.MODE_JSON))
# Out:
# {"meta": {"aMarker": "m:", "today": "d:2021-01-14", "ver": "3.0"}, "cols": [{"metaData": "s:in no particular order", "abc": "n:123.000000", "name": "firstColumn"}, {"name": "secondColumn"}], "rows": [{"firstColumn": "n:154.000000 kg", "secondColumn": "s:and counting"}, {"firstColumn": "m:", "secondColumn": "s:supported on Python 3.7+"}, {"firstColumn": "c:-27.472500,153.003000", "secondColumn": "s:Made in Australia from local and imported ingredients"}]}

# %%
# Load haystack file

# %%
import io

# %%
with open("sample/carytown.zinc") as f:
    g = haystackapi.parse(f.read(),haystackapi.MODE_ZINC)

# %%
# Filter some entity

# %%
site = g.filter("site")[0]

# %%
site
# Out:
# {'phone': '804.552.2222',
#  'store': MARKER,
#  'tz': 'New_York',
#  'area': _PintQuantity(3149.0, 'ft²'),
#  'site': MARKER,
#  'weatherRef': Ref('p:demo:r:23a44701-1af1bca9', 'Richmond, VA', True),
#  'primaryFunction': 'Retail Store',
#  'geoCountry': 'US',
#  'geoStreet': '3504 W Cary St',
#  'occupiedEnd': datetime.time(20, 0),
#  'yearBuilt': 1996.0,
#  'geoCoord': Coordinate(37.555385, -77.486903),
#  'regionRef': Ref('p:demo:r:23a44701-67faf4db', 'Richmond', True),
#  'occupiedStart': datetime.time(10, 0),
#  'geoCity': 'Richmond',
#  'dis': 'Carytown',
#  'id': Ref('p:demo:r:23a44701-a89a6c66', 'Carytown', True),
#  'geoAddr': '3504 W Cary St, Richmond, VA',
#  'geoState': 'VA',
#  'geoPostalCode': '23221',
#  'storeNum': 1.0,
#  'metro': 'Richmond'}

# %%
# Read time-series

# %%
with_his = g.filter("his")[0]

# %%
ts_uri = "sample/" + with_his["hisURI"]

# %%
with open(ts_uri) as f:
    ts = haystackapi.parse(f.read(),haystackapi.MODE_ZINC)
    print(ts)  # Print associated time-series
# Out:
# <Grid>
# 	Version: 3.0
# 	Metadata: MetadataObject{'hisStart'=datetime.datetime(2020, 1, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>), 'hisEnd'=datetime.datetime(2020, 12, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)}
# 	Columns:
# 		ts
# 		val
# 	Row    0:
# 	ts=datetime.datetime(2020, 2, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=74.0
# 	Row    1:
# 	ts=datetime.datetime(2020, 3, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=74.0
# 	Row    2:
# 	ts=datetime.datetime(2020, 4, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=69.0
# 	Row    3:
# 	ts=datetime.datetime(2020, 5, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=67.0
# 	Row    4:
# 	ts=datetime.datetime(2020, 6, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=63.0
# 	Row    5:
# 	ts=datetime.datetime(2020, 7, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=66.0
# 	Row    6:
# 	ts=datetime.datetime(2020, 8, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=67.0
# 	Row    7:
# 	ts=datetime.datetime(2020, 9, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=70.0
# 	Row    8:
# 	ts=datetime.datetime(2020, 10, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=72.0
# 	Row    9:
# 	ts=datetime.datetime(2020, 11, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=74.0
# 	Row   10:
# 	ts=datetime.datetime(2020, 12, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=75.0
# 	Row   11:
# 	ts=datetime.datetime(2021, 1, 1, 0, 0, tzinfo=<StaticTzInfo 'Etc/UTC'>)
# 	val=78.0
# </Grid>

# %%
# Save grid

# %%
with open("ontology.csv","w") as f:
    f.write(haystackapi.dump(g,haystackapi.MODE_CSV))

# %%
with open("ontology.json","w") as f:
    f.write(haystackapi.dump(g,haystackapi.MODE_JSON))

# %%
import pandas as pd

# %%
with open("sample/carytown.zinc") as f:
    grid = haystackapi.parse(f.read(), haystackapi.MODE_ZINC)

# %%
df = pd.DataFrame(grid.filter("his"))  # Convert grid to data frame

# %%
df
# Out:
#           tz tariffHis      sp                                 siteRef  \
# 0   New_York    MARKER  MARKER  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 1   New_York       NaN  MARKER  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 2   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 3   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 4   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 5   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 6   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 7   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 8   New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 9        NaN       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 10  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 11  New_York       NaN  MARKER  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 12  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 13  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 14  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 15  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 16  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
# 17  New_York       NaN     NaN  @p:demo:r:23a44701-a89a6c66 'Carytown'
#
#       kind   point         dis  \
# 0      Str  MARKER  Tariff His
# 1   Number  MARKER         NaN
# 2   Number  MARKER         NaN
# 3   Number  MARKER         NaN
# 4   Number  MARKER         NaN
# 5     Bool  MARKER         NaN
# 6     Bool  MARKER         NaN
# 7   Number  MARKER         NaN
# 8   Number  MARKER         NaN
# 9      NaN     NaN         NaN
# 10    Bool  MARKER         NaN
# 11    Bool  MARKER         NaN
# 12  Number  MARKER         NaN
# 13    Bool  MARKER         NaN
# 14    Bool  MARKER         NaN
# 15    Bool  MARKER         NaN
# 16  Number  MARKER         NaN
# 17  Number  MARKER         NaN
#
#                                                    id  \
# 0            @p:demo:r:23a44701-bbc36976 'Tariff His'
# 1   @p:demo:r:23a44701-4ea35663 'Carytown RTU-1 Zo...
# 2   @p:demo:r:23a44701-3940e690 'Carytown ElecMete...
# 3   @p:demo:r:23a44701-27a8a001 'Carytown RTU-1 Zo...
# 4   @p:demo:r:23a44701-423ebf02 'Carytown RTU-1 Di...
# 5   @p:demo:r:23a44701-3a62fd7a 'Carytown RTU-1 He...
# 6   @p:demo:r:23a44701-18bbbd7e 'Carytown RTU-1 He...
# 7   @p:demo:r:23a44701-f299239f 'Carytown ElecMete...
# 8   @p:demo:r:23a44701-0144bdd8 'Carytown RTU-1 Di...
# 9   @p:demo:r:23a44701-092f16fa 'Carytown ElecMete...
# 10  @p:demo:r:23a44701-e0edb850 'Carytown RTU-1 Co...
# 11  @p:demo:r:23a44701-5c6fd964 'Carytown Misc Occ...
# 12  @p:demo:r:23a44701-51b0b0ff 'Carytown ElecMete...
# 13  @p:demo:r:23a44701-81534688 'Carytown RTU-1 Co...
# 14  @p:demo:r:23a44701-cb53b843 'Carytown Main Lig...
# 15   @p:demo:r:23a44701-f8856742 'Carytown RTU-1 Fan'
# 16  @p:demo:r:23a44701-d83664ec 'Carytown RTU-1 Ou...
# 17  @p:demo:r:23a44701-3f2eb151 'Carytown RTU-1 Re...
#
#                                              equipRef     his  ...    cool  \
# 0   @p:demo:r:23a44701-092f16fa 'Carytown ElecMete...  MARKER  ...     NaN
# 1        @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 2   @p:demo:r:23a44701-092f16fa 'Carytown ElecMete...  MARKER  ...     NaN
# 3        @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 4        @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 5        @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 6        @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 7   @p:demo:r:23a44701-092f16fa 'Carytown ElecMete...  MARKER  ...     NaN
# 8        @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 9                                                 NaN  MARKER  ...     NaN
# 10       @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...  MARKER
# 11        @p:demo:r:23a44701-3624929f 'Carytown Misc'  MARKER  ...     NaN
# 12  @p:demo:r:23a44701-092f16fa 'Carytown ElecMete...  MARKER  ...     NaN
# 13       @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...  MARKER
# 14  @p:demo:r:23a44701-cef6cd79 'Carytown Main Lig...  MARKER  ...     NaN
# 15       @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 16       @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
# 17       @p:demo:r:23a44701-7265b064 'Carytown RTU-1'  MARKER  ...     NaN
#
#    occupied sitePoint  energy  lights costPerHour     fan  damper outside  \
# 0       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 1       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 2       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 3       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 4       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 5       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 6       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 7       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 8       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 9       NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 10      NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 11   MARKER    MARKER     NaN     NaN         NaN     NaN     NaN     NaN
# 12      NaN       NaN  MARKER     NaN         NaN     NaN     NaN     NaN
# 13      NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
# 14      NaN       NaN     NaN  MARKER     2.4 USD     NaN     NaN     NaN
# 15      NaN       NaN     NaN     NaN         NaN  MARKER     NaN     NaN
# 16      NaN       NaN     NaN     NaN         NaN     NaN  MARKER  MARKER
# 17      NaN       NaN     NaN     NaN         NaN     NaN     NaN     NaN
#
#     return
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17  MARKER
#
# [18 rows x 46 columns]
